# %%
import matplotlib
import matplotlib as mtpy
import matplotlib as mt
import matplotlib.pyplot as mtpy
import numpy as np

# %%
x1=np.array(['A','B','C','D','E'])
y1=np.array([23,14,15,29,10])
mtpy.plot(x1,y1)
mtpy.show()

# %%
mtpy.plot(x1)
mtpy.show()

# %%
mtpy.plot(y1)
mtpy.show()

# %%
mtpy.plot(y1,'o')
mtpy.show()

# %%
mtpy.plot(y1,marker='o')
mtpy.show()

# %%
mtpy.plot(y1,marker='o',ms=10)
mtpy.show()

# %%
mtpy.plot(y1,marker='o',ms=10,mec='r')
mtpy.show()

# %%
mtpy.plot(y1,marker='o',ms=10,mec='r',mfc='y')
mtpy.show()

# %%
mtpy.plot(y1,ls=':')
mtpy.show()

# %%
mtpy.plot(y1,ls='-.')
mtpy.show()

# %%
mtpy.plot(y1,ls='-.',linewidth=10)
mtpy.show()

# %%
mtpy.plot(y1,ls='-.',linewidth=2,color='c')
mtpy.show()

# %%
mtpy.plot(y1,ls='-.',linewidth=2,color='m')
mtpy.show()
